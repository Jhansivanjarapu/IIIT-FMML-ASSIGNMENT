# %% [markdown]
# <a href="https://colab.research.google.com/github/Jhansivanjarapu/IIIT-FMML-ASSIGNMENT/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-03-28 15:17:07--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   118MB/s    in 0.6s
#
# 2024-03-28 15:17:08 (118 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 11424  1601.07460v4  In this paper, we study the information-theore...    cs
# 7703   1802.09246v2  Variable selection is central to high-dimensio...  stat
# 1110   1710.07547v1  Clinical measurements collected over time are ...    cs
# 22233  1509.04610v2  We propose Macau, a powerful and flexible Baye...  stat
# 9124    1403.6397v1  Topic models extract representative word sets ...    cs
# ...             ...                                                ...   ...
# 20910  1705.03078v1  This paper uses anthropic reasoning to argue f...    cs
# 13907  1605.06714v1  Most of the problems in genetic algorithms are...    cs
# 19182   1304.1536v1  We discuss the Dempster-Shafer theory of evide...    cs
# 7672   1802.07295v1  As the prevalence and everyday use of machine ...  stat
# 3547   1711.09219v1  Kernel methods are powerful tools to capture n...  stat
#
#                                                    title  year  \
# 11424  Information-theoretic limits of Bayesian netwo...  2016
# 7703   Scalable kernel-based variable selection with ...  2018
# 1110   Learning compressed representations of blood s...  2017
# 22233  Macau: Scalable Bayesian Multi-relational Fact...  2015
# 9124                 Evaluating topic coherence measures  2014
# ...                                                  ...   ...
# 20910  An Anthropic Argument against the Future Exist...  2017
# 13907                Evolutionary Demographic Algorithms  2016
# 19182  Normalization and the Representation of Nonmon...  2013
# 7672   Attack Strength vs. Detectability Dilemma in A...  2018
# 3547                              Stacked Kernel Network  2017
#
#                                                 keywords
# 11424  [information, theoretic, structure, continuous...
# 7703   [selection, dimensional, algorithms, developed...
# 1110   [measurements, collected, naturally, represent...
# 22233  [factorization, heterogeneous, factorize, rela...
# 9124   [representative, documents, requiring, annotat...
# ...                                                  ...
# 20910  [anthropic, reasoning, likelihood, superintell...
# 13907  [algorithms, resources, technology, distribute...
# 19182  [introduce, monotonicity, diminution, plausibi...
# 7672   [prevalence, algorithms, algorithms, dramatica...
# 3547   [nonlinear, implicitly, dimensional, nonlinear...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 11424    [information, theoretic, structure, continuous...
# 7703     [selection, dimensional, algorithms, developed...
# 1110     [measurements, collected, naturally, represent...
# 22233    [factorization, heterogeneous, factorize, rela...
# 9124     [representative, documents, requiring, annotat...
#                                ...
# 6689     [embedding, efficient, converting, dimensional...
# 6373     [introduce, framework, generative, dimensional...
# 34       [information, recommender, handcrafted, repres...
# 16033    [concerned, identifying, representation, diffe...
# 7774     [supervised, techniques, particularly, dimensi...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8700 words.
# Out of those 4530 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="ea3a85e9-2726-4100-a26b-827047517cdc" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ea3a85e9-2726-4100-a26b-827047517cdc")) {                    Plotly.newPlot(                        "ea3a85e9-2726-4100-a26b-827047517cdc",                        [{"x":["essential","respectively","probability","exponential","selection","extension","structure","conditional","continuous","fundamental","procedure","characterize","byproduct","distributions","regression","inequality","information","instantiate","obtaining","variables","theoretic","theoretical","functions","supported","desirable","modification","involving","estimation","including","simulated","properties","developed","algorithm","computation","thresholding","algorithms","predictor","sparsistency","reproducing","conditions","dimension","asymptotic","interaction","advantage","different","computational","guarantee","effectiveness","established","dimensional","computing","assumption","important","collected","measurements","classified","representations","autoencoder","framework","explicitly","representing","characteristics","vectorial","compressed","classification","dimensions","naturally","multivariate","infection","alignment","missingness","represented","incorporate","specially","relational","primarily","challenging","predicting","regressions","factorize","observations","experiments","instances","prediction","heterogeneous","relations","injection","performance","specifically","factorization","annotations","philosophy","requiring","documents","individual","evaluating","distinguish","guaranteed","therefore","interpretable","scientific","coherence","representative","sometimes","intelligence","annotated","motivated","achieving","recognize","convolutional","performances","alternative","exploiting","interpret","capability","competitive","intuitive","promising","obstacles","developing","sensitivity","advancement","limitations","generation","summaries","importance","grammatical","arguments","generating","evaluation","extractive","integrate","informative","summarization","construct","indicates","abstractive","outperforms","opinionated","attention","automatic","automated","evaluated","registration","spherical","outperform","reduction","discriminant","recognition","classical","dimensionality","represent","solutions","activated","approximations","effective","simultaneous","eventually","addresses","projection","implement","classifying","classifiers","locations","detection","classifications","segmentation","successfully","extraction","preprocessing","investigated","realistic","demonstrated","recognizes","especially","identifiable","remarkable","thresholds","boundaries","proposals","refinement","coordinate","necessarily","supervised","challenges","representation","reconstruct","benchmark","parameters","discriminative","unsupervised","structures","arbitrary","reconstruction","connected","architecture","enhancement","underlying","arbitrarily","stringent"],"y":[82,97,177,48,169,80,317,108,118,90,131,41,3,125,127,6,752,7,31,111,45,148,231,20,34,17,48,216,245,71,214,191,828,167,21,613,5,0,13,139,54,24,75,84,799,273,40,187,47,180,128,66,367,79,47,18,238,22,559,77,68,104,6,23,500,47,60,21,2,45,1,88,67,10,40,19,260,91,0,2,76,580,106,223,31,97,5,903,160,30,72,7,48,59,111,52,27,23,153,26,36,15,26,27,77,76,68,78,35,354,54,103,79,22,40,114,40,108,9,61,36,3,60,137,13,87,14,25,116,240,6,48,41,25,80,21,5,272,3,165,177,105,148,28,10,101,84,16,365,108,52,118,144,4,36,248,16,17,57,43,67,39,122,45,328,9,204,88,139,30,43,53,84,6,131,6,27,8,40,26,25,24,23,229,99,368,26,202,245,100,166,128,81,96,73,245,31,117,17,3],"type":"bar"},{"x":["essential","respectively","probability","exponential","selection","extension" ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4530,), (4530, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8033333333333333

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Joint</span> <span style=''>Weakly</span> <span style=''>and</span> <span style=''>Semi</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Supervised</span> <span style=''>Deep</span> <span style=''>Learning</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.6438356164383561);'>Localization</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Classification</span> <span style=''>of</span> <span style=''>Masses</span> <span style=''>in</span> <span style=''>Breast</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>Ultrasound</span> <span style=''>Images</span> <br/><br/><span style=''>We</span> <span style=''>propose</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>framework</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.6438356164383561);'>localization</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>classification</span> <span style=''>of</span> <span style=''>masses</span> <span style=''>in</span> <span style=''>breast</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>ultrasound</span> <span style=''>(BUS)</span> <span style=''>images</span> <span style=''>In</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>particular</span> <span style=''>we</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>simultaneously</span> <span style=''>use</span> <span style=''>a</span> <span style=''>weakly</span> <span style='background-color:rgba(0, 255, 0, 0.8765432098765433);'>annotated</span> <span style=''>dataset</span> <span style=''>and</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>relatively</span> <span style=''>small</span> <span style=''>strongly</span> <span style='background-color:rgba(0, 255, 0, 0.8765432098765433);'>annotated</span> <span style=''>dataset</span> <span style=''>to</span> <span style=''>train</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.6238532110091743);'>convolutional</span> <span style=''>neural</span> <span style=''>network</span> <span style=''>detector</span> <span style=''>We</span> <span style=''>have</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>experimentally</span> <span style=''>found</span> <span style=''>that</span> <span style=''>mass</span> <span style='background-color:rgba(0, 255, 0, 0.7333333333333332);'>detectors</span> <span style=''>trained</span> <span style=''>with</span> <span style=''>small</span> <span style=''>strongly</span> <span style='background-color:rgba(0, 255, 0, 0.8765432098765433);'>annotated</span> <span style=''>datasets</span> <span style=''>are</span> <span style=''>easily</span> <span style='background-color:rgba(255, 0, 0, 0.3333333333333334);'>overfitted</span> <span style=''>whereas</span> <span style=''>those</span> <span style=''>trained</span> <span style=''>with</span> <span style=''>large</span> <span style=''>weakly</span> <span style='background-color:rgba(0, 255, 0, 0.8765432098765433);'>annotated</span> <span style=''>datasets</span> <span style=''>present</span> <span style=''>a</span> <span style=''>non</span> <span style=''>trivial</span> <span style=''>problem</span> <span style=''>To</span> <span style=''>overcome</span> <span style=''>these</span> <span style=''>problems</span> <span style=''>we</span> <span style=''>jointly</span> <span style=''>use</span> <span style=''>datasets</span> <span style=''>with</span> <span style='background-color:rgba(0, 255, 0, 0.36932305055698367);'>different</span> <span style='background-color:rgba(0, 255, 0, 0.43448275862068964);'>characteristics</span> <span style=''>in</span> <span style=''>a</span> <span style=''>hybrid</span> <span style=''>manner</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Consequently</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>sop ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Minimax</span> <span style=''>Rates</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Efficient</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Algorithms</span> <span style=''>for</span> <span style=''>Noisy</span> <span style=''>Sorting</span> <br/><br/><span style=''>There</span> <span style=''>has</span> <span style=''>been</span> <span style=''>a</span> <span style=''>recent</span> <span style=''>surge</span> <span style=''>of</span> <span style=''>interest</span> <span style=''>in</span> <span style=''>studying</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>permutation</span> <span style=''>based</span> <span style=''>models</span> <span style=''>for</span> <span style=''>ranking</span> <span style=''>from</span> <span style=''>pairwise</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>comparison</span> <span style=''>data</span> <span style=''>Despite</span> <span style=''>being</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>structurally</span> <span style=''>richer</span> <span style=''>and</span> <span style=''>more</span> <span style=''>robust</span> <span style=''>than</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>parametric</span> <span style=''>ranking</span> <span style=''>models</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>permutation</span> <span style=''>based</span> <span style=''>models</span> <span style=''>are</span> <span style=''>less</span> <span style=''>well</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>understood</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>statistically</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>generally</span> <span style=''>lack</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>efficient</span> <span style=''>learning</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithms</span> <span style=''>In</span> <span style=''>this</span> <span style=''>work</span> <span style=''>we</span> <span style=''>study</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>prototype</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>permutation</span> <span style=''>based</span> <span style=''>ranking</span> <span style=''>models</span> <span style=''>namely</span> <span style=''>the</span> <span style=''>noisy</span> <span style=''>sorting</span> <span style=''>model</span> <span style=''>We</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>establish</span> <span style=''>the</span> <span style=''>optimal</span> <span style=''>rates</span> <span style=''>of</span> <span style=''>learning</span> <span style=''>the</span> <span style=''>model</span> <span style=''>under</span> <span style=''>two</span> <span style=''>sampling</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>procedures</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Furthermore</span> <span style=''>we</span> <span style=''>provide</span> <span style=''>a</span> <span style=''>fast</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>to</span> <span style=''>achieve</span> <span style=''>near</span> <span style=''>optimal</span> <span style=''>rates</span> <span style=''>if</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>observations</span> <span style=''>are</span> <span style=''>sampled</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>independently</span> <span style=''>Along</span> <span style=''>the</span> <span style=''>way</span> <span style=''>we</span> <span style=''>discover</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>properties</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>symmetric</span> <span style=''>group</span> <span style=''>which</sp ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.3);'>Structured</span> <span style=''>Low</span> <span style=''>Rank</span> <span style=''>Matrix</span> <span style='background-color:rgba(255, 0, 0, 0.5161290322580646);'>Factorization</span> <span style=''>with</span> <span style=''>Missing</span> <span style=''>and</span> <span style=''>Grossly</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Corrupted</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Observations</span> <br/><br/><span style='background-color:rgba(255, 0, 0, 0.3);'>Recovering</span> <span style=''>low</span> <span style=''>rank</span> <span style=''>and</span> <span style=''>sparse</span> <span style=''>matrices</span> <span style=''>from</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>incomplete</span> <span style=''>or</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>corrupted</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>observations</span> <span style=''>is</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>important</span> <span style=''>problem</span> <span style=''>in</span> <span style=''>machine</span> <span style=''>learning</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>statistics</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>bioinformatics</span> <span style=''>computer</span> <span style=''>vision</span> <span style=''>as</span> <span style=''>well</span> <span style=''>as</span> <span style=''>signal</span> <span style=''>and</span> <span style=''>image</span> <span style='background-color:rgba(0, 255, 0, 0.41265822784810113);'>processing</span> <span style=''>In</span> <span style=''>theory</span> <span style=''>this</span> <span style=''>problem</span> <span style=''>can</span> <span style=''>be</span> <span style=''>solved</span> <span style=''>by</span> <span style=''>the</span> <span style=''>natural</span> <span style=''>convex</span> <span style=''>jointmixed</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>relaxations</span> <span style=''>(ie</span> <span style=''>l</span> <span style=''>1</span> <span style=''>norm</span> <span style=''>and</span> <span style=''>trace</span> <span style=''>norm)</span> <span style=''>under</span> <span style=''>certain</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>conditions</span> <span style=''>However</span> <span style=''>all</span> <span style=''>current</span> <span style=''>provable</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithms</span> <span style=''>suffer</span> <span style=''>from</span> <span style='background-color:rgba(0, 255, 0, 0.33333333333333326);'>superlinear</span> <span style=''>per</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>iteration</span> <span style=''>cost</span> <span style=''>which</span> <span style=''>severely</span> <span style=''>limits</span> <span style=''>their</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>applicability</span> <span style=''>to</span> <span style=''>large</span> <span style=''>scale</span> <span style=''>problems</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>scalable</span> <span style=''>provable</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>structured</span> <span style=''>low</span> <span style=''>rank</span> <span style=''>matrix</span> <span style='background-color:rgba(255, 0, 0, 0.5161290322580646);'>factorization</span> <span style=''>method</span> <span style=''>to</span> <span style=''>recover</span> <span style=''>low</span> <span style=''>rank</span> <span style=''>and</span> <span style=''>sparse</span> <span style=''>matrices</span> <span style=''>from</span> <span style=''>missing</span> <span style=''>and</span> <span style=''>grossly</span> <span style='background-color:rgba(0, 255, 0, 0.3);'> ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Local</span> <span style=''>Minimax</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Complexity</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Stochastic</span> <span style=''>Convex</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Optimization</span> <br/><br/><span style=''>We</span> <span style=''>extend</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>traditional</span> <span style=''>worst</span> <span style=''>case</span> <span style=''>minimax</span> <span style=''>analysis</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>stochastic</span> <span style=''>convex</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>optimization</span> <span style=''>by</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>introducing</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>localized</span> <span style=''>form</span> <span style=''>of</span> <span style=''>minimax</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>complexity</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>individual</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>functions</span> <span style=''>Our</span> <span style=''>main</span> <span style=''>result</span> <span style=''>gives</span> <span style=''>function</span> <span style=''>specific</span> <span style=''>lower</span> <span style=''>and</span> <span style=''>upper</span> <span style=''>bounds</span> <span style=''>on</span> <span style=''>the</span> <span style=''>number</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>stochastic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>subgradient</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>evaluations</span> <span style=''>needed</span> <span style=''>to</span> <span style=''>optimize</span> <span style=''>either</span> <span style=''>the</span> <span style=''>function</span> <span style=''>or</span> <span style=''>its</span> <span style=''>hardest</span> <span style=''>local</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>alternative</span> <span style=''>to</span> <span style=''>a</span> <span style=''>given</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>numerical</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>precision</span> <span style=''>The</span> <span style=''>bounds</span> <span style=''>are</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>expressed</span> <span style=''>in</span> <span style=''>terms</span> <span style=''>of</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>localized</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>computational</span> <span style=''>analogue</span> <span style=''>of</span> <span style=''>the</span> <span style=''>modulus</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>continuity</span> <span style=''>that</span> <span style=''>is</span> <span style=''>central</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>statistical</span> <span style=''>minimax</span> <span style=''>analysis</span> <span style=''>We</span> <span style=''>show</span> <span style=''>how</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>computational</span> <span style=''>modulus</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>continuity</span> <span style=''>can</span> <span style=''>be</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>explicitly</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>calculated</span> <span style=''>in</span> <span style=''>concrete</span> <span style=''>cases</span> <span style=''>and</span> <span style=''>relates</span> <span  ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	processing (0.09957173447537473)
# 	experimental (0.13740185581727338)
# 	representation (0.13133476088508209)
# 	architecture (0.08743754461099215)
# 	segmentation (0.0728051391862955)
# 	detection (0.11705924339757316)
# 	information (0.26837972876516775)
# 	convolutional (0.12633832976445397)
# 	recognition (0.1302640970735189)
# 	different (0.2851534618129907)
#
# Some Statistics words are:
# 	stochastic (0.12862862862862862)
# 	algorithm (0.38238238238238237)
# 	statistical (0.15865865865865866)
# 	theoretical (0.14364364364364365)
# 	estimation (0.18018018018018017)
# 	variables (0.14564564564564564)
# 	inference (0.1956956956956957)
# 	distribution (0.19269269269269268)
# 	dimensional (0.1881881881881882)
# 	regression (0.1856856856856857)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="45129361-dd82-420b-931e-52c786421c96" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("45129361-dd82-420b-931e-52c786421c96")) {                    Plotly.newPlot(                        "45129361-dd82-420b-931e-52c786421c96",                        [{"x":["essential","respectively","probability","exponential","selection","extension","structure","conditional","continuous","fundamental","procedure","characterize","byproduct","distributions","regression","inequality","information","instantiate","obtaining","variables","theoretic","theoretical","functions","supported","desirable","modification","involving","estimation","including","simulated","properties","developed","algorithm","computation","thresholding","algorithms","predictor","sparsistency","reproducing","conditions","dimension","asymptotic","interaction","advantage","different","computational","guarantee","effectiveness","established","dimensional","computing","assumption","important","collected","measurements","classified","representations","autoencoder","framework","explicitly","representing","characteristics","vectorial","compressed","classification","dimensions","naturally","multivariate","infection","alignment","missingness","represented","incorporate","specially","relational","primarily","challenging","predicting","regressions","factorize","observations","experiments","instances","prediction","heterogeneous","relations","injection","performance","specifically","factorization","annotations","philosophy","requiring","documents","individual","evaluating","distinguish","guaranteed","therefore","interpretable","scientific","coherence","representative","sometimes","intelligence","annotated","motivated","achieving","recognize","convolutional","performances","alternative","exploiting","interpret","capability","competitive","intuitive","promising","obstacles","developing","sensitivity","advancement","limitations","generation","summaries","importance","grammatical","arguments","generating","evaluation","extractive","integrate","informative","summarization","construct","indicates","abstractive","outperforms","opinionated","attention","automatic","automated","evaluated","registration","spherical","outperform","reduction","discriminant","recognition","classical","dimensionality","represent","solutions","activated","approximations","effective","simultaneous","eventually","addresses","projection","implement","classifying","classifiers","locations","detection","classifications","segmentation","successfully","extraction","preprocessing","investigated","realistic","demonstrated","recognizes","especially","identifiable","remarkable","thresholds","boundaries","proposals","refinement","coordinate","necessarily","supervised","challenges","representation","reconstruct","benchmark","parameters","discriminative","unsupervised","structures","arbitrary","reconstruction","connected","architecture","enhancement","underlying","arbitrarily","stringent","efficient","hindsight","adversarial","dominates","deterministic","assumptions","transition","adversarially","generated","empirical","unbounded","determined","translation","translator","addressing","concealing","synthesizing","mechanism","encryption","experimental","discriminate","generator","demonstrate","communication","discriminator","challenge","communicate","transmission","confronted","synchronization","confidential","formulate","significantly","statistical","convexity","regularization","corrected","convergence","converges","regularizer","stochastic","restricted","particular","carefully","particles","depending","denoising","propagation","distribution","application","metropolis","inference","dependence","typically","introducing","validate ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	sparsistency
# 	regressions
# 	bernstein
# 	integrations
# 	exponents
# 	semiparametric
# 	transparency
# 	explainability
# 	postulated
# 	robustify
# 	robustification
# 	exchangeability
# 	conformity
# 	overparameterized
# 	tensorflow
# 	repertoires
# 	spectrogram
# 	illustrations
# 	ferromagnetic
# 	perceptible
# Some words which never appear in Statistics papers:
# 	obstacles
# 	grammatical
# 	extractive
# 	abstractive
# 	opinionated
# 	recognizes
# 	translator
# 	concealing
# 	competency
# 	euclidian
# 	cascading
# 	copyright
# 	discontinuities
# 	watermarked
# 	watermarking
# 	watermark
# 	contourlet
# 	articulated
# 	specifies
# 	compatibility

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.0721966205837174e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7591666666666667
